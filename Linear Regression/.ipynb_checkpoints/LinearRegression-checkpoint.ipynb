# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression, HuberRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import root_mean_squared_error
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import missingno

# %%
data = pd.read_csv('data/dataset.csv', index_col=0)
data.drop([col for col in data.columns if 'future' in col], axis=1, inplace=True)

# %%
data
# Out:
#             dow_jones_open_price  dow_jones_high_price  dow_jones_low_price  \
# date
# 2003-01-01                   NaN                   NaN                  NaN
# 2003-01-02               8342.38               8608.27              8342.38
# 2003-01-03               8607.38               8635.49              8552.87
# 2003-01-06               8602.78               8800.59              8602.10
# 2003-01-07               8775.84               8802.64              8713.03
# ...                          ...                   ...                  ...
# 2025-04-15              40527.82              40791.18             40346.94
# 2025-04-16              40179.49              40416.80             39394.75
# 2025-04-17              39745.58              39745.58             38950.31
# 2025-04-18                   NaN                   NaN                  NaN
# 2025-04-21              38906.04              38906.04             37830.66
#
#             dow_jones_close_price  dow_jones_adj_close_price  \
# date
# 2003-01-01                    NaN                        NaN
# 2003-01-02                8607.52                    8607.52
# 2003-01-03                8601.69                    8601.69
# 2003-01-06                8773.57                    8773.57
# 2003-01-07                8740.59                    8740.59
# ...                           ...                        ...
# 2025-04-15               40368.96                   40368.96
# 2025-04-16               39669.39                   39669.39
# 2025-04-17               39142.23                   39142.23
# 2025-04-18                    NaN                        NaN
# 2025-04-21               38170.41                   38170.41
#
#             dow_jones_trading_volume  nasdaq_open_price  nasdaq_high_price  \
# date
# 2003-01-01                       NaN                NaN                NaN
# 2003-01-02               243910000.0            1346.93            1384.91
# 2003-01-03               234000000.0            1382.36            1389.44
# 2003-01-06               258040000.0            1390.19            1428.65
# 2003-01-07               266970000.0            1424.26            1442.26
# ...                              ...                ...                ...
# 2025-04-15               529800000.0           16842.39           16979.96
# 2025-04-16               737550000.0           16499.69           16600.37
# 2025-04-17               657400000.0           16399.97           16408.51
# 2025-04-18                       NaN                NaN                NaN
# 2025-04-21               604790000.0           16052.76           16066.79
#
#             nasdaq_low_price  nasdaq_close_price  ...  \
# date                                              ...
# 2003-01-01               NaN                 NaN  ...
# 2003-01-02           1336.98             1384.85  ...
# 2003-01-03           1374.61             1387.08  ...
# 2003-01-06           1390.09             1421.32  ...
# 2003-01-07           1416.23             1431.57  ...
# ...                      ...                 ...  ...
# 2025-04-15          16753.22            16823.17  ...
# 2025-04-16          16066.46            16307.16  ...
# 2025-04-17          16181.17            16286.45  ...
# 2025-04-18               NaN                 NaN  ...
# 2025-04-21          15685.33            15870.90  ...
#
#             usd_to_uk_exchange_rate  jp_to_usd_exchange_rate  \
# date
# 2003-01-01                      NaN                      NaN
# 2003-01-02                   1.5975                   119.86
# 2003-01-03                   1.6045                   119.85
# 2003-01-06                   1.6080                   119.06
# 2003-01-07                   1.6055                   120.18
# ...                             ...                      ...
# 2025-04-15                   1.3223                   143.10
# 2025-04-16                   1.3247                   142.56
# 2025-04-17                   1.3259                   142.33
# 2025-04-18                   1.3279                   142.22
# 2025-04-21                      NaN                      NaN
#
#             brent_crude_oil_price  cushing_crude_oil_price  \
# date
# 2003-01-01                    NaN                      NaN
# 2003-01-02                  30.32                    31.97
# 2003-01-03                  31.43                    33.26
# 2003-01-06                  31.43                    32.29
# 2003-01-07                  30.78                    31.20
# ...                           ...                      ...
# 2025-04-15                    NaN                      NaN
# 2025-04-16                    NaN                      NaN
# 2025-04-17                    NaN                      NaN
# 2025-04-18                    NaN                      NaN
# 2025-04-21                    NaN                      NaN
#
#             treasury_1_year_rate  treasury_10_year_rate  \
# date
# 2003-01-01                   NaN                    NaN
# 2003-01-02                  1.42                   4.07
# 2003-01-03                  1.41                   4.05
# 2003-01-06                  1.44                   4.09
# 2003-01-07                  1.40                   4.04
# ...                          ...                    ...
# 2025-04-15                  3.99                   4.35
# 2025-04-16                  3.96                   4.29
# 2025-04-17                  3.99                   4.34
# 2025-04-18                   NaN                    NaN
# 2025-04-21                   NaN                    NaN
#
#             breakeven_inflation_5_year  breakeven_inflation_10_year  \
# date
# 2003-01-01                         NaN                          NaN
# 2003-01-02                        1.30                         1.64
# 2003-01-03                        1.28                         1.62
# 2003-01-06                        1.31                         1.63
# 2003-01-07                        1.28                         1.62
# ...                                ...                          ...
# 2025-04-15                        2.31                         2.19
# 2025-04-16                        2.29                         2.17
# 2025-04-17                        2.26                         2.23
# 2025-04-18                         NaN                          NaN
# 2025-04-21                        2.25                         2.22
#
#             bank_prime_loan_rate  federal_funds_rate
# date
# 2003-01-01                   NaN                 NaN
# 2003-01-02                  4.25                1.30
# 2003-01-03                  4.25                1.12
# 2003-01-06                  4.25                1.22
# 2003-01-07                  4.25                1.20
# ...                          ...                 ...
# 2025-04-15                  7.50                4.33
# 2025-04-16                  7.50                4.33
# 2025-04-17                  7.50                4.33
# 2025-04-18                   NaN                4.33
# 2025-04-21                   NaN                 NaN
#
# [5819 rows x 29 columns]

# %%
data.isnull().sum()
# Out:
# dow_jones_open_price           208
# dow_jones_high_price           208
# dow_jones_low_price            208
# dow_jones_close_price          208
# dow_jones_adj_close_price      208
# dow_jones_trading_volume       208
# nasdaq_open_price              208
# nasdaq_high_price              208
# nasdaq_low_price               208
# nasdaq_close_price             208
# nasdaq_adj_close_price         208
# nasdaq_trading_volume          208
# sp_open_price                  208
# sp_high_price                  208
# sp_low_price                   208
# sp_close_price                 208
# sp_adj_close_price             208
# sp_trading_volume              208
# usd_to_eur_exchange_rate       229
# usd_to_uk_exchange_rate        229
# jp_to_usd_exchange_rate        229
# brent_crude_oil_price          165
# cushing_crude_oil_price        228
# treasury_1_year_rate           241
# treasury_10_year_rate          241
# breakeven_inflation_5_year     240
# breakeven_inflation_10_year    240
# bank_prime_loan_rate           195
# federal_funds_rate             220
# dtype: int64

# %%
missingno.matrix(data, figsize=(30,5))
# Out:
# <Axes: >

# %%
data.dropna(inplace=True)

# %%
data.rename(columns={' usd_to_eur_exchange_rate': ' eur_to_usd_exchange_rate', ' usd_to_uk_exchange_rate': ' uk_to_usd_exchange_rate'}, inplace=True)

# %%
data[' eur_to_usd_exchange_rate'] = 1/data[' eur_to_usd_exchange_rate']
data[' uk_to_usd_exchange_rate'] = 1/data[' uk_to_usd_exchange_rate']

# %%
data.describe()
# Out:
#        dow_jones_open_price  dow_jones_high_price  dow_jones_low_price  \
# count           5494.000000           5494.000000          5494.000000
# mean           19284.307739          19392.743724         19171.002956
# std             9755.383055           9802.329092          9704.363786
# min             6547.010000           6709.610000          6469.950000
# 25%            11123.072500          11195.652500         11048.822500
# 50%            16088.690000          16195.565000         15996.410000
# 75%            26178.870000          26296.667500         26033.050000
# max            45054.360000          45073.630000         44799.740000
#
#        dow_jones_close_price  dow_jones_adj_close_price  \
# count            5494.000000                5494.000000
# mean            19287.631911               19287.631911
# std              9755.733701                9755.733701
# min              6547.050000                6547.050000
# 25%             11124.860000               11124.860000
# 50%             16095.420000               16095.420000
# 75%             26155.742500               26155.742500
# max             45014.040000               45014.040000
#
#        dow_jones_trading_volume  nasdaq_open_price  nasdaq_high_price  \
# count              5.494000e+03        5494.000000        5494.000000
# mean               2.549666e+08        5999.424079        6039.870686
# std                1.320728e+08        4789.693019        4824.073359
# min                8.410000e+06        1266.990000        1279.590000
# 25%                1.593425e+08        2304.832500        2317.230000
# 50%                2.441150e+08        4123.600000        4137.400000
# 75%                3.215700e+08        8049.320000        8106.552500
# max                1.412960e+09       20114.980000       20204.580000
#
#        nasdaq_low_price  nasdaq_close_price  ...  uk_to_usd_exchange_rate  \
# count       5494.000000         5494.000000  ...              5494.000000
# mean        5954.636099         5999.872936  ...                 0.669192
# std         4750.650289         4789.364046  ...                 0.100385
# min         1253.220000         1268.640000  ...                 0.473844
# 25%         2288.072500         2304.805000  ...                 0.600691
# 50%         4092.960000         4123.515000  ...                 0.650449
# 75%         8003.892500         8045.255000  ...                 0.766034
# max        20004.730000        20173.890000  ...                 0.934317
#
#        jp_to_usd_exchange_rate  brent_crude_oil_price  \
# count              5494.000000            5494.000000
# mean                110.346240              72.333782
# std                  17.845649              26.065154
# min                  75.720000               9.120000
# 25%                 101.840000              52.295000
# 50%                 109.580000              70.740000
# 75%                 117.800000              90.622500
# max                 161.730000             143.950000
#
#        cushing_crude_oil_price  treasury_1_year_rate  treasury_10_year_rate  \
# count              5494.000000           5494.000000            5494.000000
# mean                 68.690309              1.795291               3.036356
# std                  22.930368              1.777692               1.135236
# min                 -36.980000              0.040000               0.520000
# 25%                  50.615000              0.230000               2.100000
# 50%                  68.280000              1.210000               2.940000
# 75%                  85.590000              3.105000               4.070000
# max                 145.310000              5.490000               5.260000
#
#        breakeven_inflation_5_year  breakeven_inflation_10_year  \
# count                 5494.000000                  5494.000000
# mean                     1.936664                     2.093493
# std                      0.571098                     0.400409
# min                     -2.240000                     0.040000
# 25%                      1.620000                     1.850000
# 50%                      1.970000                     2.195000
# 75%                      2.330000                     2.360000
# max                      3.590000                     3.020000
#
#        bank_prime_loan_rate  federal_funds_rate
# count           5494.000000         5494.000000
# mean               4.776483            1.674345
# std                1.851450            1.869103
# min                3.250000            0.040000
# 25%                3.250000            0.130000
# 50%                4.000000            0.980000
# 75%                5.500000            2.547500
# max                8.500000            5.410000
#
# [8 rows x 29 columns]

# %%
def draw_heatmap(data):
    plt.figure(figsize=(30, 30))
    sns.heatmap(data.corr(), annot=True, cmap='YlGnBu')

# %%
draw_heatmap(data)

# %%
for col in data.columns:
    data[col] = data[col].apply(lambda x: np.log(x+100))

# %%
features = [
[' dow_jones_open_price', ' dow_jones_high_price', ' dow_jones_low_price', ' dow_jones_close_price', ' dow_jones_adj_close_price', ' dow_jones_trading_volume'],
[' nasdaq_open_price', ' nasdaq_high_price', ' nasdaq_low_price', ' nasdaq_close_price', ' nasdaq_adj_close_price', ' nasdaq_trading_volume'],
[' sp_open_price', ' sp_high_price', ' sp_low_price', ' sp_close_price', ' sp_adj_close_price'],
[' eur_to_usd_exchange_rate', ' uk_to_usd_exchange_rate', ' jp_to_usd_exchange_rate'],
[' treasury_1_year_rate', ' treasury_10_year_rate'],
[' breakeven_inflation_5_year', ' breakeven_inflation_10_year'],
[' bank_prime_loan_rate', ' federal_funds_rate'],
]
labels = {' brent_crude_oil_price': [data[' brent_crude_oil_price'].mean(), data[' brent_crude_oil_price'].std()],
          ' cushing_crude_oil_price': [data[' cushing_crude_oil_price'].mean(), data[' cushing_crude_oil_price'].std()]}

# %%
scaler = StandardScaler()
data = pd.DataFrame(scaler.fit_transform(data), columns=data.columns)

# %%
models = {
    'LinearRegression': LinearRegression(),
    'HuberRegressor': HuberRegressor()
}

# %%
def plotting(res):
    plt.plot(res.index, res.y_pred, label='predict')
    plt.plot(res.index, res.y_test, label='test')
    plt.legend()
    plt.show()

def training(name, feature, label):
    X_train, X_test, y_train, y_test = train_test_split(data[feature], data[label], test_size=0.2, random_state=42)
    models[name].fit(X_train, y_train)
    y_pred = models[name].predict(X_test)
    y_pred, y_test = np.exp(y_pred*labels[label][1]+labels[label][0])-100, np.exp(y_test*labels[label][1]+labels[label][0])-100
    print(name, 'Label:', label)
    print('Features:', *feature)
    print('RMSE:', root_mean_squared_error(y_pred, y_test))
    print('-------------------------------------------------')
    return pd.DataFrame({'y_pred': y_pred, 'y_test': y_test}).sort_index()

# %%
for name in models:
    for label in labels:
        for feature in features:
            training(name, feature, label)
# Out:
# LinearRegression Label:  brent_crude_oil_price
# Features:  dow_jones_open_price  dow_jones_high_price  dow_jones_low_price  dow_jones_close_price  dow_jones_adj_close_price  dow_jones_trading_volume
# RMSE: 24.808691235937935
# -------------------------------------------------
# LinearRegression Label:  brent_crude_oil_price
# Features:  nasdaq_open_price  nasdaq_high_price  nasdaq_low_price  nasdaq_close_price  nasdaq_adj_close_price  nasdaq_trading_volume
# RMSE: 26.27815079644754
# -------------------------------------------------
# LinearRegression Label:  brent_crude_oil_price
# Features:  sp_open_price  sp_high_price  sp_low_price  sp_close_price  sp_adj_close_price
# RMSE: 26.27264478099941
# -------------------------------------------------
# LinearRegression Label:  brent_crude_oil_price
# Features:  eur_to_usd_exchange_rate  uk_to_usd_exchange_rate  jp_to_usd_exchange_rate
# RMSE: 22.38813473966777
# -------------------------------------------------
# LinearRegression Label:  brent_crude_oil_price
# Features:  treasury_1_year_rate  treasury_10_year_rate
# RMSE: 26.5262927214281
# -------------------------------------------------
# LinearRegression Label:  brent_crude_oil_price
# Features:  breakeven_inflation_5_year  breakeven_inflation_10_year
# RMSE: 22.332045235578867
# -------------------------------------------------
# LinearRegression Label:  brent_crude_oil_price
# Features:  bank_prime_loan_rate  federal_funds_rate
# RMSE: 25.80404667220151
# -------------------------------------------------
# LinearRegression Label:  cushing_crude_oil_price
# Features:  dow_jones_open_price  dow_jones_high_price  dow_jones_low_price  dow_jones_close_price  dow_jones_adj_close_price  dow_jones_trading_volume
# RMSE: 22.10192495592824
# -------------------------------------------------
# LinearRegression Label:  cushing_crude_oil_price
# Features:  nasdaq_open_price  nasdaq_high_price  nasdaq_low_price  nasdaq_close_price  nasdaq_adj_close_price  nasdaq_trading_volume
# RMSE: 22.975794095922982
# -------------------------------------------------
# LinearRegression Label:  cushing_crude_oil_price
# Features:  sp_open_price  sp_high_price  sp_low_price  sp_close_price  sp_adj_close_price
# RMSE: 23.004298737448806
# -------------------------------------------------
# LinearRegression Label:  cushing_crude_oil_price
# Features:  eur_to_usd_exchange_rate  uk_to_usd_exchange_rate  jp_to_usd_exchange_rate
# RMSE: 19.03050059917732
# -------------------------------------------------
# LinearRegression Label:  cushing_crude_oil_price
# Features:  treasury_1_year_rate  treasury_10_year_rate
# RMSE: 23.142711676474796
# -------------------------------------------------
# LinearRegression Label:  cushing_crude_oil_price
# Features:  breakeven_inflation_5_year  breakeven_inflation_10_year
# RMSE: 19.168927302960387
# -------------------------------------------------
# LinearRegression Label:  cushing_crude_oil_price
# Features:  bank_prime_loan_rate  federal_funds_rate
# RMSE: 22.552825809464757
# -------------------------------------------------
# HuberRegressor Label:  brent_crude_oil_price
# Features:  dow_jones_open_price  dow_jones_high_price  dow_jones_low_price  dow_jones_close_price  dow_jones_adj_close_price  dow_jones_trading_volume
# RMSE: 24.66662422646755
# -------------------------------------------------
# HuberRegressor Label:  brent_crude_oil_price
# Features:  nasdaq_open_price  nasdaq_high_price  nasdaq_low_price  nasdaq_close_price  nasdaq_adj_close_price  nasdaq_trading_volume
# RMSE: 26.54370472480502
# -------------------------------------------------
# HuberRegressor Label:  brent_crude_oil_price
# Features:  sp_open_price  sp_high_price  sp_low_price  sp_close_price  sp_adj_close_price
# RMSE: 26.39035036859813
# -------------------------------------------------
# HuberRegressor Label:  brent_crude_oil_price
# Features:  eur_to_usd_exchange_rate  uk_to_usd_exchange_rate  jp_to_usd_exchange_rate
# RMSE: 22.60175725104899
# -------------------------------------------------
# HuberRegressor Label:  brent_crude_oil_price
# Features:  treasury_1_year_rate  treasury_10_year_rate
# RMSE: 26.672096761499517
# -------------------------------------------------
# HuberRegressor Label:  brent_crude_oil_price
# Features:  breakeven_inflation_5_year  breakeven_inflation_10_year
# RMSE: 22.43726851206465
# -------------------------------------------------
# HuberRegressor Label:  brent_crude_oil_price
# Features:  bank_prime_loan_rate  federal_funds_rate
# RMSE: 26.08645672611489
# -------------------------------------------------
# HuberRegressor Label:  cushing_crude_oil_price
# Features:  dow_jones_open_price  dow_jones_high_price  dow_jones_low_price  dow_jones_close_price  dow_jones_adj_close_price  dow_jones_trading_volume
# RMSE: 21.98639809922808
# -------------------------------------------------
# HuberRegressor Label:  cushing_crude_oil_price
# Features:  nasdaq_open_price  nasdaq_high_price  nasdaq_low_price  nasdaq_close_price  nasdaq_adj_close_price  nasdaq_trading_volume
# RMSE: 23.112294570688498
# -------------------------------------------------
# HuberRegressor Label:  cushing_crude_oil_price
# Features:  sp_open_price  sp_high_price  sp_low_price  sp_close_price  sp_adj_close_price
# RMSE: 23.029412720605812
# -------------------------------------------------
# HuberRegressor Label:  cushing_crude_oil_price
# Features:  eur_to_usd_exchange_rate  uk_to_usd_exchange_rate  jp_to_usd_exchange_rate
# RMSE: 19.149200583873284
# -------------------------------------------------
# HuberRegressor Label:  cushing_crude_oil_price
# Features:  treasury_1_year_rate  treasury_10_year_rate
# RMSE: 23.29411786121981
# -------------------------------------------------
# HuberRegressor Label:  cushing_crude_oil_price
# Features:  breakeven_inflation_5_year  breakeven_inflation_10_year
# RMSE: 19.24510663956933
# -------------------------------------------------
# HuberRegressor Label:  cushing_crude_oil_price
# Features:  bank_prime_loan_rate  federal_funds_rate
# RMSE: 22.626575022031144
# -------------------------------------------------

# %%
total_features = list(set(data.columns) - set(labels))
training('LinearRegression', total_features, ' brent_crude_oil_price')
training('LinearRegression', total_features, ' cushing_crude_oil_price')
training('HuberRegressor', total_features, ' brent_crude_oil_price')
training('HuberRegressor', total_features, ' cushing_crude_oil_price')
# Out:
# LinearRegression Label:  brent_crude_oil_price
# Features:  nasdaq_high_price  nasdaq_low_price  eur_to_usd_exchange_rate  dow_jones_adj_close_price  dow_jones_low_price  sp_low_price  sp_high_price  sp_adj_close_price  federal_funds_rate  dow_jones_high_price  nasdaq_trading_volume  jp_to_usd_exchange_rate  dow_jones_open_price  nasdaq_open_price  sp_trading_volume  treasury_1_year_rate  bank_prime_loan_rate  dow_jones_trading_volume  breakeven_inflation_5_year  nasdaq_close_price  nasdaq_adj_close_price  dow_jones_close_price  sp_close_price  sp_open_price  treasury_10_year_rate  uk_to_usd_exchange_rate  breakeven_inflation_10_year
# RMSE: 11.850047391136902
# -------------------------------------------------
# LinearRegression Label:  cushing_crude_oil_price
# Features:  nasdaq_high_price  nasdaq_low_price  eur_to_usd_exchange_rate  dow_jones_adj_close_price  dow_jones_low_price  sp_low_price  sp_high_price  sp_adj_close_price  federal_funds_rate  dow_jones_high_price  nasdaq_trading_volume  jp_to_usd_exchange_rate  dow_jones_open_price  nasdaq_open_price  sp_trading_volume  treasury_1_year_rate  bank_prime_loan_rate  dow_jones_trading_volume  breakeven_inflation_5_year  nasdaq_close_price  nasdaq_adj_close_price  dow_jones_close_price  sp_close_price  sp_open_price  treasury_10_year_rate  uk_to_usd_exchange_rate  breakeven_inflation_10_year
# RMSE: 10.636881713752386
# -------------------------------------------------
# C:\Users\Le Tam Quang\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_huber.py:342: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# HuberRegressor Label:  brent_crude_oil_price
# Features:  nasdaq_high_price  nasdaq_low_price  eur_to_usd_exchange_rate  dow_jones_adj_close_price  dow_jones_low_price  sp_low_price  sp_high_price  sp_adj_close_price  federal_funds_rate  dow_jones_high_price  nasdaq_trading_volume  jp_to_usd_exchange_rate  dow_jones_open_price  nasdaq_open_price  sp_trading_volume  treasury_1_year_rate  bank_prime_loan_rate  dow_jones_trading_volume  breakeven_inflation_5_year  nasdaq_close_price  nasdaq_adj_close_price  dow_jones_close_price  sp_close_price  sp_open_price  treasury_10_year_rate  uk_to_usd_exchange_rate  breakeven_inflation_10_year
# RMSE: 11.978142607446483
# -------------------------------------------------
# HuberRegressor Label:  cushing_crude_oil_price
# Features:  nasdaq_high_price  nasdaq_low_price  eur_to_usd_exchange_rate  dow_jones_adj_close_price  dow_jones_low_price  sp_low_price  sp_high_price  sp_adj_close_price  federal_funds_rate  dow_jones_high_price  nasdaq_trading_volume  jp_to_usd_exchange_rate  dow_jones_open_price  nasdaq_open_price  sp_trading_volume  treasury_1_year_rate  bank_prime_loan_rate  dow_jones_trading_volume  breakeven_inflation_5_year  nasdaq_close_price  nasdaq_adj_close_price  dow_jones_close_price  sp_close_price  sp_open_price  treasury_10_year_rate  uk_to_usd_exchange_rate  breakeven_inflation_10_year
# RMSE: 10.66968220271601
# -------------------------------------------------
# C:\Users\Le Tam Quang\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_huber.py:342: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
#          y_pred     y_test
# 8     18.655638  32.417194
# 12    18.912158  34.617349
# 15    23.377635  34.977375
# 17    19.875870  32.697213
# 23    25.401500  33.907299
# ...         ...        ...
# 5480  70.091220  70.050268
# 5483  75.902848  71.870437
# 5486  75.805224  67.430027
# 5487  75.012966  62.419577
# 5490  88.405929  62.629596
#
# [1099 rows x 2 columns]

# %%
res = training('LinearRegression', total_features, ' cushing_crude_oil_price')
print(res)
plotting(res)
# Out:
# LinearRegression Label:  cushing_crude_oil_price
# Features:  nasdaq_high_price  nasdaq_low_price  eur_to_usd_exchange_rate  dow_jones_adj_close_price  dow_jones_low_price  sp_low_price  sp_high_price  sp_adj_close_price  federal_funds_rate  dow_jones_high_price  nasdaq_trading_volume  jp_to_usd_exchange_rate  dow_jones_open_price  nasdaq_open_price  sp_trading_volume  treasury_1_year_rate  bank_prime_loan_rate  dow_jones_trading_volume  breakeven_inflation_5_year  nasdaq_close_price  nasdaq_adj_close_price  dow_jones_close_price  sp_close_price  sp_open_price  treasury_10_year_rate  uk_to_usd_exchange_rate  breakeven_inflation_10_year
# RMSE: 10.636881713752386
# -------------------------------------------------
#           y_pred     y_test
# 8      19.165599  32.417194
# 12     21.799279  34.617349
# 15     25.653583  34.977375
# 17     21.146898  32.697213
# 23     27.924956  33.907299
# ...          ...        ...
# 5480   70.434939  70.050268
# 5483   78.669849  71.870437
# 5486   76.001132  67.430027
# 5487   79.554610  62.419577
# 5490  113.282260  62.629596
#
# [1099 rows x 2 columns]

# %%
pca = PCA(n_components=1)

stocks = features[0]+features[1]+features[2]
data['PCA0'] = pca.fit_transform(data[stocks])

t = 1
for feature in features[3:]:
    data[f'PCA{t}'] = pca.fit_transform(data[feature])
    t += 1

pca_features = [f'PCA{i}' for i in range(t)]

# %%
draw_heatmap(data[pca_features+[' brent_crude_oil_price', ' cushing_crude_oil_price']])

# %%
training('LinearRegression', pca_features, ' brent_crude_oil_price')
training('LinearRegression', pca_features, ' cushing_crude_oil_price')
training('HuberRegressor', pca_features, ' brent_crude_oil_price')
training('HuberRegressor', pca_features, ' cushing_crude_oil_price')
# Out:
# LinearRegression Label:  brent_crude_oil_price
# Features: PCA0 PCA1 PCA2 PCA3 PCA4
# RMSE: 20.47149138888175
# -------------------------------------------------
# LinearRegression Label:  cushing_crude_oil_price
# Features: PCA0 PCA1 PCA2 PCA3 PCA4
# RMSE: 17.585956945506744
# -------------------------------------------------
# HuberRegressor Label:  brent_crude_oil_price
# Features: PCA0 PCA1 PCA2 PCA3 PCA4
# RMSE: 20.570925549774667
# -------------------------------------------------
# HuberRegressor Label:  cushing_crude_oil_price
# Features: PCA0 PCA1 PCA2 PCA3 PCA4
# RMSE: 17.635204054695905
# -------------------------------------------------
#          y_pred     y_test
# 8     29.572674  32.417194
# 12    28.861814  34.617349
# 15    30.835293  34.977375
# 17    30.403014  32.697213
# 23    30.894851  33.907299
# ...         ...        ...
# 5480  78.172455  70.050268
# 5483  77.097507  71.870437
# 5486  80.019845  67.430027
# 5487  75.528315  62.419577
# 5490  79.734044  62.629596
#
# [1099 rows x 2 columns]

# %%
res = training('LinearRegression', pca_features, ' cushing_crude_oil_price')
plotting(res)
# Out:
# LinearRegression Label:  cushing_crude_oil_price
# Features: PCA0 PCA1 PCA2 PCA3 PCA4
# RMSE: 17.585956945506744
# -------------------------------------------------
